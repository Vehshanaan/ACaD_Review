# %% [markdown]
# # 本周内容：
#
#  - 数字控制系统初探（ADDA，采保器）
#  - Z变换

# %% [markdown]
# # 1. AD(模转数转换器)

# %% [markdown]
# AD就是一种连续时间的被控对象和电脑之间的接口。它将连续时间信号转换为数字信号。
#
#
# 结构：
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 两步走:
#  - 采样：
