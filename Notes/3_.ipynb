# %% [markdown]
# # 本周的内容
#
#  - 从状态空间方程求系统的时域响应
#  - 判断能控能观性

# %% [markdown]
# # 1. 用状态方程计算系统的时域响应
#
# 时域响应分两种：
#  - 自由响应：输入为0的响应
#  - 受迫响应：输入不为0的响应
#
# 要计算时域输出，就先计算状态的变化，再用状态推算输出
#
# 自由响应：
#  - 状态响应：
#    ![image.png](attachment:image.png)
#  - 输出响应：
#   ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 受迫响应：
#
#  - 状态响应：
#   ![image-3.png](attachment:image-3.png)
#  - 输出响应：
#   ![image-4.png](attachment:image-4.png)

# %% [markdown]
# 怎么求$\phi$：
#
# 假设起始时间$t_0=0$。
#
# 1. 原始方法：
#
# ![image.png](attachment:image.png)
#
# 这招除非$A^k$很小，高次会消失，不然不要用这个。
#
# 2. 简化方法：**要求初始状态值$x(t_0)==0$**
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 2. 能控性
#
# 定义：如果一个动态系统是完全状态可控的，那在任何时间，可以构造一个不受约束的控制向量，此向量可以在有限时间内将任意状态转移到目标状态
